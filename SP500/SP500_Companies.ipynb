# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
from bs4 import BeautifulSoup
import requests
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
resp = requests.get("https://stockmarketmba.com/stocksinthesp500.php")
soup = BeautifulSoup(resp.text, 'lxml')
table = soup.find('table', {'id': 'ipos'})
rows = table.find('tbody').find_all('tr')

tickers = []
industries = []

for row in rows:
    ticker = row.find_all('td')[0].text.strip()
    tickers.append(ticker)
    industry = row.find_all('td')[4].text.strip()
    industries.append(industry)

df_list = []
no_data = []

for i in range(len(tickers)):
    try:
        temp = pdr.get_data_yahoo(tickers[i], start='2010-12-01', end='2020-12-31')
        temp['symbol'] = tickers[i]
        temp['industry'] = industries[i]
        df_list.append(temp)
    except:
        no_data.append(tickers[i])

main_df = pd.concat(df_list)
main_df.to_csv("SP500 stock OHLC.csv")
print(main_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
temp = pdr.get_data_yahoo('BRK-B', start='2010-12-01', end='2020-12-31')
temp['symbol'] = 'BRK-B'
temp['industry'] = industries[tickers.index('BRK.B')]
df_list.append(temp)
main_df = pd.concat(df_list)
main_df['industry'] = np.where(main_df.industry=='Information technology', 'Information Technology', main_df.industry)
main_df.to_csv("SP500 stock OHLC.csv")
print(main_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-12-01   25.500715   25.858370   25.472103   25.836910   23.462572
# 2010-12-02   25.736767   26.351931   25.672388   26.266094   23.852320
# 2010-12-03   26.108727   26.888412   26.094421   26.809729   24.345999
# 2010-12-06   26.680973   26.752504   26.502146   26.559372   24.118643
# 2010-12-07   26.888412   27.095852   26.824034   26.881260   24.410952
# ...                ...         ...         ...         ...         ...
# 2020-12-23  222.630005  224.910004  222.610001  224.240005  224.240005
# 2020-12-24  224.600006  227.130005  224.210007  226.529999  226.529999
# 2020-12-28  228.089996  230.149994  227.360001  228.410004  228.410004
# 2020-12-29  230.500000  231.100006  229.100006  229.570007  229.570007
# 2020-12-30  229.539993  230.589996  229.080002  229.649994  229.649994
#
# ...

# %%
num = 10
for i in range(num):
    temp = main_df.iloc[int(len(main_df)*i/10):int(len(main_df)*(i+1)/10), ]
    temp.to_csv("SP500 stock OHLC {}.csv".format(i+1))

# %%
length = 0
for i in range(num):
    length += len(pd.read_csv("SP500 stock OHLC {}.csv".format(i+1), header=0, index_col=0, parse_dates=[0]))
print(length)
# Out:
# 1218213
